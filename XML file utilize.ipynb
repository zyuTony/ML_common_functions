# %%
#!pip install opencv-python

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %run common_functions.ipynb

import cv2
from scipy.spatial import distance
import os

# %%
import xml.etree.ElementTree as ET

# parse xml file
tree = ET.parse("./annotations/maksssksksss0.xml") 
root = tree.getroot() # get root object

# %%
xmin = []
for i in root.findall('object'):
    for j in i.findall('bndbox'):
        xmin.append(j.find('xmin').text)

# %%
 xmin = [int(i) for i in xmin]

# %%
face_model = cv2.CascadeClassifier('./images/maksssksksss0.png')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\core\src\persistence.cpp:682: error: (-5:Bad argument) Input file is invalid in function 'cv::FileStorage::Impl::open'
#
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-65-71aed7bc3c24> in <module>
# ----> 1 face_model = cv2.CascadeClassifier('./images/maksssksksss0.png')
#
# SystemError: <class 'cv2.CascadeClassifier'> returned a result with an error set

# %%
img = cv2.imread("./images/maksssksksss0.png")

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
